# %% [markdown]
# # Importar Bibliotecas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import utils

# %% [markdown]
# # Leer dataset como DataFrame

# %%
# Se lee el dataset como csv que fue creado sintéticamente
df = pd.read_csv('dataset_U1.csv')

# Mostramos un resumen del dataset para darnos una idea general de cómo es
df
# Out:
#              id                         nombre  semestre  promedio  ingresos  \
# 0     IDHFI3552  Caridad Leonor Padrón Cavazos         7        86   13580.0
# 1     IDVOH5097       Aurelio Fabiola Anguiano         4        89   15993.0
# 2     IDFYS5079          Omar Amalia Sepúlveda         8        89   11008.0
# 3     IDSCE4123   Pamela Aida Cuellar Valverde         5        62   30926.0
# 4     IDYMU9480          Óscar Olivárez Nájera         7        66   24968.0
# ...         ...                            ...       ...       ...       ...
# 9995  IDURC8308    Inés Cynthia Madrid Salinas         7        86   17337.0
# 9996  IDJLX9083                   Mitzy Puente        10        74       NaN
# 9997  IDNCQ0036                Raquel Longoria         3        91   26994.0
# 9998  IDWJQ8803           Lic. Andrea Cisneros        10        87       NaN
# 9999  IDLPD1164    Maximiliano Alfonso Fuentes         5        68   22850.0
#
#       opinion_campus  trabaja  distancia_universidad  edad tipo_vivienda  \
# 0                 10    False                    NaN    21        Propia
# 1                  4     True                    1.0    22      Alquiler
# 2                  4    False                    1.0    18        Propia
# 3                 10    False                    1.0    17        Propia
# 4                 10    False                    1.0    26      Alquiler
# ...              ...      ...                    ...   ...           ...
# 9995              10     True                    1.0    37      Alquiler
# 9996               1    False                   10.0    17      Alquiler
# 9997              10     True                    NaN    27        Propia
# 9998               7     True                    3.0    26      Alquiler
# 9999               9     True                    NaN    23        Propia
#
#       horas_estudio  desertor
# 0                29         0
# 1                 5         0
# 2                11         0
# 3                12         0
# 4                17         0
# ...             ...       ...
# 9995             70         0
# 9996             88         0
# 9997             71         0
# 9998             74         0
# 9999            100         0
#
# [10000 rows x 12 columns]

# %%
# Para experimentos rápidos, reducimos el dataset a 500 muestras aleatorias
df_reduced =df.sample(500, random_state=42)
df_reduced.to_csv('dataset_U1_reduced.csv', index=False)

# %% [markdown]
# # Ver tipos de datos

# %%
# Nos permite ver si los datos son booleanos, numéricos reales o enteros, o si son strings (object)
df.dtypes
# Out:
# id                           str
# nombre                       str
# semestre                   int64
# promedio                   int64
# ingresos                 float64
# opinion_campus             int64
# trabaja                     bool
# distancia_universidad    float64
# edad                       int64
# tipo_vivienda                str
# horas_estudio              int64
# desertor                   int64
# dtype: object

# %% [markdown]
# # Calcular modas, medianas y medias

# %% [markdown]
# ## Modas

# %%
# Esta funcion nos devuelve la moda de cada columna del DataFrame
df.mode()
# Out:
#              id            nombre  semestre  promedio  ingresos  \
# 0     IDAAE3765      Bruno Flórez       1.0      74.0    8300.0
# 1     IDAAJ6279  Cornelio Vásquez       NaN       NaN       NaN
# 2     IDAAK9953     Dolores Salas       NaN       NaN       NaN
# 3     IDAAN0414     Gloria Fierro       NaN       NaN       NaN
# 4     IDAAN8457    Isabel Carrión       NaN       NaN       NaN
# ...         ...               ...       ...       ...       ...
# 9995  IDZZR7800               NaN       NaN       NaN       NaN
# 9996  IDZZU2201               NaN       NaN       NaN       NaN
# 9997  IDZZU4785               NaN       NaN       NaN       NaN
# 9998  IDZZU7053               NaN       NaN       NaN       NaN
# 9999  IDZZY4781               NaN       NaN       NaN       NaN
#
#       opinion_campus trabaja  distancia_universidad  edad tipo_vivienda  \
# 0               10.0   False                    1.0  17.0        Propia
# 1                NaN     NaN                    NaN   NaN           NaN
# 2                NaN     NaN                    NaN   NaN           NaN
# 3                NaN     NaN                    NaN   NaN           NaN
# 4                NaN     NaN                    NaN   NaN           NaN
# ...              ...     ...                    ...   ...           ...
# 9995             NaN     NaN                    NaN   NaN           NaN
# 9996             NaN     NaN                    NaN   NaN           NaN
# 9997             NaN     NaN                    NaN   NaN           NaN
# 9998             NaN     NaN                    NaN   NaN           NaN
# 9999             NaN     NaN                    NaN   NaN           NaN
#
#       horas_estudio  desertor
# 0              91.0       0.0
# 1               NaN       NaN
# 2               NaN       NaN
# 3               NaN       NaN
# 4               NaN       NaN
# ...             ...       ...
# 9995            NaN       NaN
# 9996            NaN       NaN
# 9997            NaN       NaN
# 9998            NaN       NaN
# 9999            NaN       NaN
#
# [10000 rows x 12 columns]

# %%
# Ahora vemos las modas pero solo con las columnas que nos interesan (en los nombre no tiene sentido estadístico encontrar la moda)
df[['semestre', 'promedio', 'ingresos', 'opinion_campus', 'distancia_universidad', 'edad', 'tipo_vivienda', 'horas_estudio', 'desertor']].mode()
# Out:
#    semestre  promedio  ingresos  opinion_campus  distancia_universidad  edad  \
# 0         1        74    8300.0              10                    1.0    17
#
#   tipo_vivienda  horas_estudio  desertor
# 0        Propia             91         0

# %% [markdown]
# ## Medianas

# %%
# De igual forma obtenemos las medianas de las columnas que consideramos importantes
df[['semestre', 'promedio', 'ingresos', 'opinion_campus', 'distancia_universidad', 'edad', 'horas_estudio']].median()
# Out:
# semestre                     6.0
# promedio                    80.0
# ingresos                 19972.0
# opinion_campus               8.0
# distancia_universidad        3.0
# edad                        20.0
# horas_estudio               50.0
# dtype: float64

# %% [markdown]
# ## Medias

# %%
# Igual con las medias, o promedios aritméticos
df[['semestre', 'promedio', 'ingresos', 'opinion_campus', 'distancia_universidad', 'edad', 'horas_estudio', 'desertor']].mean()
# Out:
# semestre                     5.497200
# promedio                    79.752400
# ingresos                 20319.281485
# opinion_campus               7.271800
# distancia_universidad        4.264385
# edad                        20.888600
# horas_estudio               50.270400
# desertor                     0.187600
# dtype: float64

# %% [markdown]
# # Comprobar comportamiento de los datos

# %% [markdown]
# Queremos asegurarnos que el dataset se comporte como lo definimos.
# De igual forma aprovechamos para medio sondearlo.

# %%
# En esta celda graficamos el histograma de la variable "semestre"

column = 'semestre'

# Calculate mode, mean, median, and std
mode_val = df[column].mode()[0]
mean_val = df[column].mean()
median_val = df[column].median()
std_val = df[column].std()

plt.figure(figsize=(10, 6))
plt.hist(df[column], bins=range(1, 12), edgecolor='black', align='left', rwidth=0.8)

# Add vertical lines for mode, mean, median, and std
plt.axvline(mode_val, color='red', linestyle='--', linewidth=2, label=f'Mode: {mode_val:.2f}')
plt.axvline(mean_val, color='green', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color='orange', linestyle='-.', linewidth=2, label=f'Median: {median_val:.2f}')
plt.axvline(mean_val - std_val, color='blue', linestyle=':', linewidth=2, label=f'Std: ±{std_val:.2f}')
plt.axvline(mean_val + std_val, color='blue', linestyle=':', linewidth=2)

# Customize the x-ticks to match the numbers in the data
plt.xticks(range(min(df[column]), max(df[column])+1 ))

# Show the plot
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# En esta celda graficamos el histograma de la variable "promedio"

column = 'promedio'

# Calculate mode, mean, median, and std
mode_val = df[column].mode()[0]
mean_val = df[column].mean()
median_val = df[column].median()
std_val = df[column].std()

# Define los bordes de los bins para crear exactamente 10 barras entre 60 y 100
bins = np.linspace(60, 100, 11)  # 10 intervalos -> 11 bordes

plt.figure(figsize=(10, 6))
plt.hist(df[column], bins=bins, edgecolor='black', align='mid', rwidth=0.8)

# Add vertical lines for mode, mean, median, and std
plt.axvline(mode_val, color='red', linestyle='--', linewidth=2, label=f'Mode: {mode_val:.2f}')
plt.axvline(mean_val, color='green', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color='orange', linestyle='-.', linewidth=2, label=f'Median: {median_val:.2f}')
plt.axvline(mean_val - std_val, color='blue', linestyle=':', linewidth=2, label=f'Std: ±{std_val:.2f}')
plt.axvline(mean_val + std_val, color='blue', linestyle=':', linewidth=2)

# Ajusta las marcas del eje X para que coincidan con los valores medios de los bins
plt.xticks(np.arange(60, 101, 4))  # Aquí 4 es el ancho de cada intervalo (100-60)/10

# Mostrar el gráfico con título y etiquetas
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# En esta celda graficamos el histograma de la variable "ingresos"

column = 'ingresos'

# Calculate mode, mean, median, and std
mode_val = df[column].mode()[0]
mean_val = df[column].mean()
median_val = df[column].median()
std_val = df[column].std()

plt.figure(figsize=(10, 6))
plt.hist(df[column], bins=np.arange(int(min(df[column])), int(max(df[column])) + 2, max(df[column] - min(df[column]))/10), 
         edgecolor='black', align='left', rwidth=0.8)

# Add vertical lines for mode, mean, median, and std
plt.axvline(mode_val, color='red', linestyle='--', linewidth=2, label=f'Mode: {mode_val:.2f}')
plt.axvline(mean_val, color='green', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color='orange', linestyle='-.', linewidth=2, label=f'Median: {median_val:.2f}')
plt.axvline(mean_val - std_val, color='blue', linestyle=':', linewidth=2, label=f'Std: ±{std_val:.2f}')
plt.axvline(mean_val + std_val, color='blue', linestyle=':', linewidth=2)

# Customize the x-ticks to match the numbers in the data
plt.xticks(np.arange(min(df[column]), max(df[column])+1, 5000))

# Show the plot
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# En esta celda graficamos el histograma de la variable "opinion_campus"

column = 'opinion_campus'

# Calculate mode, mean, median, and std
mode_val = df[column].mode()[0]
mean_val = df[column].mean()
median_val = df[column].median()
std_val = df[column].std()

plt.figure(figsize=(10, 6))
plt.hist(df[column], bins=range(1, 12), edgecolor='black', align='left', rwidth=0.8)

# Add vertical lines for mode, mean, median, and std
plt.axvline(mode_val, color='red', linestyle='--', linewidth=2, label=f'Mode: {mode_val:.2f}')
plt.axvline(mean_val, color='green', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color='orange', linestyle='-.', linewidth=2, label=f'Median: {median_val:.2f}')
plt.axvline(mean_val - std_val, color='blue', linestyle=':', linewidth=2, label=f'Std: ±{std_val:.2f}')
plt.axvline(mean_val + std_val, color='blue', linestyle=':', linewidth=2)

# Customize the x-ticks to match the numbers in the data
plt.xticks(range(min(df[column]), max(df[column])+1 ))

# Show the plot
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# En esta celda graficamos el histograma de la variable "trabaja"

column = 'trabaja'

plt.figure(figsize=(10, 6))
plt.hist(df[column].astype(int), 
         bins=[-0.5, 0.5, 1.5],  # Definimos bordes para alinear las barras con 0 y 1
         edgecolor='black', align='mid', rwidth=0.8)

# Configurar las etiquetas del eje X como 'False' y 'True'
plt.xticks([0, 1], labels=['False', 'True'])

# Títulos y etiquetas
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# %%
# En esta celda graficamos el histograma de la variable "distancia_universidad"

column = 'distancia_universidad'

# Calculate mode, mean, median, and std
mode_val = df[column].mode()[0]
mean_val = df[column].mean()
median_val = df[column].median()
std_val = df[column].std()

plt.figure(figsize=(10, 6))
plt.hist(df[column], 
         bins=10, 
         edgecolor='black', align='left', rwidth=0.8)

# Add vertical lines for mode, mean, median, and std
plt.axvline(mode_val, color='red', linestyle='--', linewidth=2, label=f'Mode: {mode_val:.2f}')
plt.axvline(mean_val, color='green', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color='orange', linestyle='-.', linewidth=2, label=f'Median: {median_val:.2f}')
plt.axvline(mean_val - std_val, color='blue', linestyle=':', linewidth=2, label=f'Std: ±{std_val:.2f}')
plt.axvline(mean_val + std_val, color='blue', linestyle=':', linewidth=2)

plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# En esta celda graficamos el histograma de la variable "edad"

column = 'edad'

# Calculate mode, mean, median, and std
mode_val = df[column].mode()[0]
mean_val = df[column].mean()
median_val = df[column].median()
std_val = df[column].std()

plt.figure(figsize=(10, 6))
plt.hist(df[column], 
         bins=np.arange(int(min(df[column])), int(max(df[column])) + 2, max(df[column] - min(df[column]))/10), 
         edgecolor='black', align='left', rwidth=0.8)

# Add vertical lines for mode, mean, median, and std
plt.axvline(mode_val, color='red', linestyle='--', linewidth=2, label=f'Mode: {mode_val:.2f}')
plt.axvline(mean_val, color='green', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color='orange', linestyle='-.', linewidth=2, label=f'Median: {median_val:.2f}')
plt.axvline(mean_val - std_val, color='blue', linestyle=':', linewidth=2, label=f'Std: ±{std_val:.2f}')
plt.axvline(mean_val + std_val, color='blue', linestyle=':', linewidth=2)

plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# En esta celda graficamos el histograma de la variable "tipo_vivienda"

column = 'tipo_vivienda'

plt.figure(figsize=(10, 6))
plt.hist(df[column], 
         bins=2, 
         edgecolor='black', align='mid', rwidth=0.8)
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.xticks(df[column].unique())
plt.ylabel('Frequency')
plt.show()

# %%
# En esta celda graficamos el histograma de la variable "horas_estudio"

column = 'horas_estudio'

# Calculate mode, mean, median, and std
mode_val = df[column].mode()[0]
mean_val = df[column].mean()
median_val = df[column].median()
std_val = df[column].std()

plt.figure(figsize=(10, 6))
plt.hist(df[column], 
         bins=np.arange(int(min(df[column])), int(max(df[column])) + 2, max(df[column] - min(df[column]))/10), 
         edgecolor='black', align='left', rwidth=0.8)

# Add vertical lines for mode, mean, median, and std
plt.axvline(mode_val, color='red', linestyle='--', linewidth=2, label=f'Mode: {mode_val:.2f}')
plt.axvline(mean_val, color='green', linestyle='--', linewidth=2, label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color='orange', linestyle='-.', linewidth=2, label=f'Median: {median_val:.2f}')
plt.axvline(mean_val - std_val, color='blue', linestyle=':', linewidth=2, label=f'Std: ±{std_val:.2f}')
plt.axvline(mean_val + std_val, color='blue', linestyle=':', linewidth=2)

plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# En esta celda graficamos el histograma de la variable clase "desertor"

column = 'desertor'

plt.figure(figsize=(10, 6))
plt.hist(df[column], 
         bins=2, 
         edgecolor='black', align='mid', rwidth=0.8)
plt.title(f'Histogram of {column}')
plt.xlabel('Value')
plt.xticks(df[column].unique())
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Ahora con todos los datos estadisticos

# %%
# Esta funcion nos da directamente todos los datos estadísticos del DataFrame, para no sacarlos individualmente, también incluye los cuartiles
df.describe()
# Out:
#            semestre      promedio      ingresos  opinion_campus  \
# count  10000.000000  10000.000000   8107.000000    10000.000000
# mean       5.497200     79.752400  20319.281485        7.271800
# std        2.893964     11.743368   8143.080849        2.833254
# min        1.000000     60.000000   8300.000000        1.000000
# 25%        3.000000     70.000000  14035.000000        5.000000
# 50%        6.000000     80.000000  19972.000000        8.000000
# 75%        8.000000     90.000000  25908.500000       10.000000
# max       10.000000    100.000000  49329.000000       10.000000
#
#        distancia_universidad          edad  horas_estudio      desertor
# count            7977.000000  10000.000000   10000.000000  10000.000000
# mean                4.264385     20.888600      50.270400      0.187600
# std                 3.632390      3.855733      35.786128      0.390412
# min                 1.000000     17.000000       1.000000      0.000000
# 25%                 1.000000     17.000000      16.000000      0.000000
# 50%                 3.000000     20.000000      50.000000      0.000000
# 75%                 7.000000     23.000000      85.000000      0.000000
# max                25.000000     39.000000     100.000000      1.000000

# %%
# Obtenemos el Coeficiente de Variación de cada variable
CV = df.describe().loc['std']/df.describe().loc['mean']
CV
# Out:
# semestre                 0.526443
# promedio                 0.147248
# ingresos                 0.400756
# opinion_campus           0.389622
# distancia_universidad    0.851797
# edad                     0.184586
# horas_estudio            0.711873
# desertor                 2.081087
# dtype: float64

# %% [markdown]
# # Distribuciones con distintas propiedades estadísticas

# %% [markdown]
# En esta sección queremos mostrar diferentes tipos de distribuciones con comportamientos diferentes dadas sus medias, medianas y desviación estándar

# %%
# Aproximamos un conjunto de datos con media 50, mediana 50, y desviación estándar 10

desired_sample_size = 300
desired_min = 1
desired_max = 100
desired_median = 50
desired_mean = 50
desired_std = 5
mean_error = 5
std_error = 5


list_numbers_1 = utils.generate_numbers(desired_sample_size, desired_min, desired_max, desired_median, desired_mean, desired_std, mean_error, std_error, max_iter=10000)

print("List:", list_numbers_1)
print("Mean:", np.mean(list_numbers_1))
print("Standard Deviation:", np.std(list_numbers_1))
print("Median:", np.median(list_numbers_1))
# Out:
# List: [1.0, 31.822170714246155, 32.37278705354186, 32.372787063541864, 32.372787073541865, 34.17135430018178, 34.738103129829256, 35.410770025578536, 35.41077003557854, 35.41077004557854, 36.06887560438299, 36.06887561438299, 36.352625148924325, 36.352625158924326, 36.46368488271438, 36.54409517050949, 36.544095180509494, 36.544095190509495, 36.544095200509496, 36.5440952105095, 36.5440952205095, 36.574604953354594, 36.574604963354595, 36.78676137532928, 36.78676138532928, 36.78676139532928, 36.78676140532928, 36.78676141532928, 36.78676142532928, 37.34646246656146, 37.34646247656146, 38.3348637528353, 38.423795461205195, 38.423795471205196, 38.48578522360209, 38.485785233602094, 38.485785243602095, 38.485785253602096, 38.517773543506614, 38.517773553506615, 38.93615126272201, 39.473348519566024, 39.745474420259775, 39.745474430259776, 39.74547444025978, 39.74547445025978, 39.74547446025978, 39.74547447025978, 39.74547448025978, 39.74547449025978, 40.411492205821006, 41.11395419125395, 41.113954201253954, 41.40968271425003, 41.40968272425003, 41.40968273425003, 41.409682744250034, 42.11559687782553, 42.11559688782553, 42.11559689782553, 42.115596907825534, 42.115596917825535, 42.20739021271127, 42.20739022271127, 42.20739023271127, 42.20739024271127, 42.20739025271127, 42.20739026271127, 42.20739027271127, 42.20739028271127, 42.207390292711274, 42.207390302711275, 42.207390312711276, 42.20739032271128, 42.32890535929136, 42.438238047021606, 42.43823805702161, 42.43823806702161, 42.43823807702161, 42.497883693265884, 42.497883703265884, 42.937011200015654, 43.01233939661915, 43.353576694524214, 43.353576704524215, 43.353576714524216, 43.35357672452422, 43.459384451942924, 43.459384461942925, 43.459384471942926, 43.45938448194293, 43.45938449194293, 43.45938450194293, 43.45938451194293, 43.45938452194293, 43.45938453194293, 43.45938454194293, 43.45938455194293, 43.45938456194293, 43.459384571942934, 43.459384581942935, 43.74295843600623, 43.74295844600623, 43.74295845600623, 43.74295846600623, 43.74295847600623, 43.96585604465405, 43.965856054654054, 43.98271060857487, 43.98271061857487, 43.98271062857487, 43.98271063857487, 43.98271064857487, 43.982710658574874, 44.439140894995816, 45.445092963918476, 46.074919115897885, 46.23916656632705, 46.23916657632705, 46.23916658632705, 46.23916659632705, 46.23916660632705, 46.239166616327054, 46.239166626327055, 46.239166636327056, 46.23916664632706, 46.23916665632706, 46.23916666632706, 46.23916667632706, 47.34934152848957, 47.34934153848957, 47.34934154848957, 47.34934155848957, 47.34934156848957, 47.459378236066, 47.459378246066, 47.459378256066, 47.459378266066004, 47.459378276066005, 47.459378286066006, 47.512745206764514, 48.81126167681498, 48.81126168681498, 49.29845068185122, 49.29845069185122, 49.46890690649361, 49.82432398395489, 49.82432399395489, 49.82432400395489, 49.82432401395489, 50.17567598604511, 50.17567599604511, 50.17567600604511, 50.17567601604511, 50.17567602604511, 50.235253576832086, 50.23525358683209, 50.23525359683209, 51.23702161368478, 51.23702162368478, 51.82454837594013, 51.82454838594013, 51.824548395940134, 51.824548405940135, 51.824548415940136, 52.29985577563769, 52.29985578563769, 52.29985579563769, 52.29985580563769, 52.29985581563769, 52.950795958296794, 52.950795968296795, 53.21984640168952, 53.219846411689524, 53.219846421689525, 53.219846431689525, 53.219846441689526, 53.21984645168953, 53.21984646168953, 53.21984647168953, 53.36262310953016, 53.36262311953016, 53.362623129530164, 53.362623139530164, 53.362623149530165, 53.362623159530166, 53.36752140913186, 53.36752141913186, 53.36752142913186, 53.563631632685166, 53.563631642685166, 53.56363165268517, 53.56363166268517, 53.7013256277326, 53.91527663357243, 53.91527664357243, 53.915276653572434, 53.915276663572435, 53.915276673572436, 53.915276683572436, 54.460157919074604, 54.460157929074605, 54.460157939074605, 54.460157949074606, 54.46015795907461, 54.558434907144324, 54.558434917144325, 55.6 ...
# Mean: 49.992491503109555
# Standard Deviation: 9.986517211964044
# Median: 50.0

# %%
# Graficamos los datos
utils.plot_histogram_with_stats(list_numbers_1, bins=7)

# %%
# Aproximamos un conjunto de datos con media 50, mediana 50, y desviación estándar 20

desired_sample_size = 300
desired_min = 1
desired_max = 100
desired_median = 50
desired_mean = 50
desired_std = 15
mean_error = 5
std_error = 5


list_numbers_2 = utils.generate_numbers(desired_sample_size, desired_min, desired_max, desired_median, desired_mean, desired_std, mean_error, std_error, max_iter=10000)

print("List:", list_numbers_2)
print("Mean:", np.mean(list_numbers_2))
print("Standard Deviation:", np.std(list_numbers_2))
print("Median:", np.median(list_numbers_2))
# Out:
# List: [1.0, 12.184059768654658, 12.736808703861598, 13.652579312004415, 16.24411244994967, 16.496041724824117, 18.265743125214566, 18.265743135214567, 18.405169951325377, 19.29580659374856, 19.960993206048105, 19.960993216048106, 19.960993226048107, 20.250772984397663, 20.250772994397664, 20.37909422622551, 20.63494602477313, 20.63494603477313, 20.63494604477313, 20.681574124483912, 21.361003723392642, 21.361003733392643, 21.361003743392644, 21.361003753392644, 21.781775079661347, 22.903984075344315, 23.2760281963265, 23.2760282063265, 23.2760282163265, 23.276028226326503, 23.559185007999076, 23.559185017999077, 23.559185027999078, 24.20994759737116, 24.742891710554964, 24.742891720554965, 24.742891730554966, 24.742891740554967, 26.38698582937056, 26.38698583937056, 26.38698584937056, 26.904187940747523, 26.904187950747524, 26.92095329444468, 26.92095330444468, 26.92095331444468, 27.390214498128685, 27.390214508128686, 27.390214518128687, 27.7739778683604, 28.02910386940755, 28.02910387940755, 28.107154517317777, 28.17544728293182, 28.231725259952974, 28.997070225638037, 29.140780502229603, 29.140780512229604, 29.140780522229605, 29.140780532229606, 29.790213706041804, 29.790213716041805, 29.790213726041806, 29.790213736041807, 29.825843082312566, 30.58199604229695, 30.80269460083579, 30.80269461083579, 30.80269462083579, 30.80269463083579, 30.802694640835792, 30.895839381780753, 30.895839391780754, 30.895839401780755, 30.895839411780756, 33.382637713944625, 33.382637723944626, 33.38263773394463, 33.40167174044118, 33.40167175044118, 33.40167176044118, 33.40167177044118, 33.401671780441184, 33.401671790441185, 34.732308272380635, 34.732308282380636, 34.73230829238064, 34.73230830238064, 34.73230831238064, 34.73230832238064, 34.73230833238064, 34.73230834238064, 34.73230835238064, 34.73230836238064, 34.73230837238064, 34.732308382380644, 36.7806867707512, 37.40127526981763, 37.40127527981763, 38.06450705604224, 38.06450706604224, 38.06450707604224, 38.06450708604224, 38.11642964415978, 39.24370032132804, 39.24370033132804, 39.243700341328044, 39.87948908302226, 39.87948909302226, 40.23388332724284, 40.65803018212958, 41.00662900600378, 41.00662901600378, 41.00662902600378, 41.00662903600378, 41.00662904600378, 41.39380822961124, 42.09704710812387, 42.09704711812387, 42.09704712812387, 42.4768451938307, 42.9871952404439, 43.20817131602971, 43.208171326029714, 43.208171336029714, 43.208171346029715, 43.208171356029716, 43.83548844944302, 43.83548845944302, 46.579879832029725, 46.579879842029726, 46.69861192401176, 46.69861193401176, 46.69861194401176, 48.23416183633583, 48.23416184633583, 48.647619467906274, 48.91439235381127, 48.914392363811274, 48.914392373811275, 49.63601379629833, 49.63601380629833, 49.63601381629833, 49.93529745273137, 49.93529746273137, 49.93529747273137, 49.93529748273137, 49.93529749273137, 49.93529750273137, 49.935297512731374, 50.064702487268626, 50.06470249726863, 50.06470250726863, 51.99742161457535, 51.99742162457535, 51.99742163457535, 51.997421644575354, 53.17157434115295, 53.17157435115295, 53.55127740171666, 54.21134248610571, 54.25557097773204, 55.00005127886706, 55.172616693612405, 55.172616703612405, 55.2326988548497, 55.2326988648497, 55.83179581706774, 55.831795827067744, 55.854576239214204, 55.854576249214205, 56.439646068381194, 56.439646078381195, 56.439646088381195, 56.439646098381196, 56.617863749082595, 56.617863759082596, 56.62927908835143, 56.62927909835143, 56.706703434895154, 56.84433100855915, 56.84433101855915, 56.844331028559154, 56.844331038559154, 56.844331048559155, 56.844331058559156, 56.84433106855916, 56.90787970608702, 56.907879716087024, 57.40161349074291, 57.40161350074291, 57.40161351074291, 58.642527918113416, 58.64252792811342, 58.666979887528214, 58.666979897528215, 58.666979907528216, 58.66697991752822, 59.019585806847374, 59.019585816847375, 59.019585826847376, 59.01958583684738, 59.01958584684738, 59.15802822130154, 59.15802823130154, 60.13211112965531, 62.733748 ...
# Mean: 49.999101778538964
# Standard Deviation: 19.997980975332045
# Median: 50.0

# %%
utils.plot_histogram_with_stats(list_numbers_2, bins=5)

# %%
# Aproximamos un conjunto de datos con media 60, mediana 80, y desviación estándar 24

desired_sample_size = 300
desired_min = 1
desired_max = 100
desired_median = 80
desired_mean = 50
desired_std = 15
mean_error = 10
std_error = 10


list_numbers_3 = utils.generate_numbers(desired_sample_size, desired_min, desired_max, desired_median, desired_mean, desired_std, mean_error, std_error, max_iter=10000)

print("List:", list_numbers_3)
print("Mean:", np.mean(list_numbers_3))
print("Standard Deviation:", np.std(list_numbers_3))
print("Median:", np.median(list_numbers_3))
# Out:
# List: [1.0, 7.182907738224768, 15.734942493452492, 18.10669515567363, 18.10669516567363, 18.94903892629287, 19.456106028600853, 22.07665037313062, 22.07665038313062, 22.11596803159497, 22.332569177719197, 23.18141591057754, 23.181415920577543, 23.55414960849124, 23.55414961849124, 23.737702095485268, 23.73770210548527, 23.73770211548527, 23.73770212548527, 23.73770213548527, 24.29336333882521, 24.29336334882521, 24.40537711262945, 24.40537712262945, 24.42981113707926, 24.42981114707926, 24.679974487394993, 27.103709977391492, 27.61333035559813, 27.61333036559813, 27.61333037559813, 27.613330385598132, 27.613330395598133, 27.613330405598134, 27.795374387558155, 27.795374397558156, 27.795374407558157, 27.795374417558158, 27.79537442755816, 27.927659418988075, 28.28715613473868, 28.28715614473868, 28.287156154738682, 28.287156164738683, 28.287156174738683, 30.480625150586146, 30.480625160586147, 30.480625170586148, 30.808252980830087, 30.961879711756033, 30.961879721756034, 31.17919184260475, 31.179191852604752, 31.179191862604753, 31.179191872604754, 31.179191882604755, 31.179191892604756, 31.239461518061688, 31.23946152806169, 32.199198005039406, 32.19919801503941, 32.45785940534938, 32.93672688726668, 32.93672689726668, 34.76627578653619, 34.76627579653619, 34.76627580653619, 34.828672714235296, 34.8286727242353, 35.09074009769166, 35.09074010769166, 35.09074011769166, 35.09074012769166, 35.09074013769166, 35.09074014769166, 37.588514429331866, 37.58851443933187, 37.58851444933187, 38.364405177729736, 38.36440518772974, 39.51690554426882, 39.53388569655587, 39.53388570655587, 39.79597046896836, 39.795970478968364, 39.795970488968365, 40.59244635908403, 40.59244636908403, 40.69037065983615, 41.15198462044999, 41.34535244343744, 41.34535245343744, 41.34535246343744, 41.345352473437444, 41.345352483437445, 41.345352493437446, 41.34535250343745, 41.34535251343745, 41.34535252343745, 44.23709669329867, 44.30485617867802, 44.30485618867802, 45.62588133152556, 45.62588134152556, 45.625881351525564, 45.625881361525565, 45.625881371525566, 45.625881381525566, 45.62588139152557, 48.27347381744711, 48.27347382744711, 48.27347383744711, 48.97152205676592, 48.97152206676592, 48.97152207676592, 48.97152208676592, 48.97152209676592, 49.02328218636529, 49.023282196365294, 49.29523565954967, 49.29523566954967, 49.30167748720446, 49.30167749720446, 49.52393109077757, 50.47340774446605, 50.47340775446605, 50.88281099787907, 50.88281100787907, 51.62670833396123, 51.62670834396123, 51.626708353961234, 52.18867267617877, 52.86034103574956, 52.860341045749564, 52.860341055749565, 52.860341065749566, 54.013128365275314, 54.013128375275315, 54.013128385275316, 54.01312839527532, 54.01312840527532, 55.11129312249664, 55.11129313249664, 55.61702077543415, 56.70572246945805, 56.70572247945805, 56.951853023814756, 58.54141128322894, 62.01305404395965, 79.98456995353581, 80.01543004646419, 80.01672379573348, 80.01672380573348, 80.01672381573347, 80.01672382573346, 80.01672383573346, 80.01672384573345, 80.01672385573345, 80.01672386573344, 80.01672387573343, 80.01672388573343, 80.01672389573342, 80.01672390573341, 80.04272424034856, 80.04272425034856, 80.04272426034855, 80.04272427034854, 80.04272428034854, 80.04272429034853, 80.04272430034852, 80.04272431034852, 80.04272432034851, 80.0427243303485, 80.0427243403485, 80.0427243503485, 80.04272436034849, 80.04272437034848, 80.04272438034847, 80.04272439034847, 80.04272440034846, 80.04272441034846, 80.04272442034845, 80.04272443034844, 80.04272444034844, 80.04272445034843, 80.04272446034842, 80.04272447034842, 80.04272448034841, 80.0427244903484, 80.0427245003484, 80.04272451034839, 80.055640000861, 80.055640010861, 80.2092323784881, 80.20923238848809, 80.20923239848808, 80.55067582381696, 80.55067583381695, 80.55067584381695, 80.55067585381694, 80.55067586381693, 80.55067587381693, 80.58326107466208, 80.58326108466207, 80.58326109466206, 80.58326110466206, 80.58326111466205, 80.58326112466204, 80.58326113466 ...
# Mean: 59.98647393269809
# Standard Deviation: 24.1286196205779
# Median: 80.0

# %%
utils.plot_histogram_with_stats(list_numbers_3, bins=7)

# %%
# Aproximamos un conjunto de datos con media 40, mediana 30, y desviación estándar 24

desired_sample_size = 300
desired_min = 1
desired_max = 100
desired_median = 30
desired_mean = 40
desired_std = 15
mean_error = 10
std_error = 10


list_numbers_4 = utils.generate_numbers(desired_sample_size, desired_min, desired_max, desired_median, desired_mean, desired_std, mean_error, std_error, max_iter=10000)

print("List:", list_numbers_4)
print("Mean:", np.mean(list_numbers_4))
print("Standard Deviation:", np.std(list_numbers_4))
print("Median:", np.median(list_numbers_4))
# Out:
# List: [1.0, 2.853343160244136, 4.0001368430888355, 4.0001368530888355, 6.272540310102943, 7.2065529743048256, 7.2065529843048255, 7.206552994304825, 7.567445251414692, 7.567445261414692, 7.567445271414692, 7.567445281414692, 7.567445291414692, 7.567445301414692, 7.567445311414692, 9.873890392035875, 9.873890402035876, 9.873890412035877, 9.873890422035878, 9.873890432035878, 9.87389044203588, 10.105751031297682, 11.68815241128124, 11.688152421281242, 12.105685609763148, 12.105685619763149, 12.10568562976315, 12.10568563976315, 12.105685649763151, 12.461833221742095, 12.461833231742096, 12.461833241742097, 12.461833251742098, 12.461833261742099, 12.4618332717421, 12.4618332817421, 12.461833291742101, 12.461833301742102, 12.461833311742103, 12.972822244907462, 12.972822254907463, 12.972822264907464, 12.972822274907465, 12.972822284907465, 12.972822294907466, 12.972822304907467, 12.972822314907468, 12.997776119745806, 12.997776129745807, 12.997776139745808, 12.997776149745809, 13.918120199707191, 13.918120209707192, 14.0070859183424, 14.0070859283424, 14.007085938342401, 14.54858334382924, 14.54858335382924, 14.548583363829241, 14.548583373829242, 14.806467773473674, 14.806467783473675, 14.806467793473676, 16.229210469473518, 16.81945012972408, 16.81945013972408, 16.81945014972408, 17.280184407287955, 17.889263602754326, 18.806274199904266, 18.806274209904267, 19.485465472319085, 19.485465482319086, 19.485465492319086, 19.485465502319087, 19.485465512319088, 19.48546552231909, 20.09715397499137, 20.436752888305474, 20.436752898305475, 20.436752908305476, 20.69716799939824, 20.807883555176048, 20.80788356517605, 20.80788357517605, 20.80788358517605, 20.80788359517605, 20.807883605176052, 20.807883615176053, 20.807883625176053, 20.807883635176054, 20.807883645176055, 20.807883655176056, 20.807883665176057, 21.532559017630284, 21.63994981200689, 21.63994982200689, 22.68642518813653, 22.68642519813653, 22.68642520813653, 22.68642521813653, 24.49805609256212, 24.756159020976842, 24.821722966433516, 24.821722976433517, 24.821722986433517, 24.821722996433518, 24.82172300643352, 25.094644636191507, 25.128977394512635, 25.128977404512636, 25.128977414512637, 25.19883046281167, 25.19883047281167, 25.28089801532228, 25.28089802532228, 25.28089803532228, 25.602591920475305, 25.602591930475306, 25.602591940475307, 25.602591950475308, 25.60259196047531, 25.60259197047531, 25.60259198047531, 25.60259199047531, 25.611877329031245, 25.611877339031246, 25.611877349031246, 25.611877359031247, 26.064884985270822, 26.662768120708318, 26.66276813070832, 27.182945786679714, 27.182945796679714, 27.182945806679715, 27.500143632330282, 27.500143642330283, 27.500143652330284, 27.597403577859758, 27.735406192641435, 28.787386725402445, 28.787386735402446, 29.132707268647682, 29.132707278647683, 29.90997956001935, 29.909979570019352, 29.91988233742626, 29.91988234742626, 29.91988235742626, 29.91988236742626, 30.08011763257374, 33.656637570758114, 33.656637580758115, 34.63603090056425, 34.63603091056425, 34.63603092056425, 34.80779702940791, 36.55479798318787, 36.55479799318787, 36.66345631421734, 36.668606578539254, 38.129741176559826, 38.129741186559826, 38.12974119655983, 38.12974120655983, 38.69988531115903, 39.52480512441113, 39.52480513441113, 40.0621213889644, 40.0621213989644, 42.1392269701542, 42.48843058194086, 42.48843059194086, 42.48843060194086, 42.48843061194086, 42.488430621940864, 42.488430631940865, 42.488430641940866, 42.48843065194087, 43.83941800326937, 43.83941801326937, 44.262184367070425, 46.250473565150436, 48.05034693684433, 48.881865452994056, 48.88186546299406, 49.44074607122973, 49.692766647861895, 50.72323990150369, 50.72323991150369, 50.72323992150369, 50.94860379526522, 50.94860380526522, 51.38954101024112, 51.55694937964937, 51.55694938964937, 51.76242228267156, 51.76242229267156, 52.55997840722444, 53.842847395901885, 53.842847405901885, 53.89100000558183, 53.89100001558183, 53.89100002558183, 54.22142811730567, 54.307378322972 ...
# Mean: 39.98850871478781
# Standard Deviation: 24.97912428429346
# Median: 30.0

# %%
utils.plot_histogram_with_stats(list_numbers_4, bins=7)

# %%
from scipy import stats
from scipy.stats import skewnorm

# Function to estimate mode from histogram
def estimate_mode(data):
    counts, bins = np.histogram(data, bins=100, density=True)
    bin_centers = (bins[:-1] + bins[1:]) / 2
    mode_index = np.argmax(counts)
    return bin_centers[mode_index]

# -------------------------------
# Right-Skewed (Positive Skew) Distribution - Gamma
# -------------------------------
shape, scale = 2, 2
right_skewed_data = np.random.gamma(shape, scale, size=10000)

mean_right = np.mean(right_skewed_data)
median_right = np.median(right_skewed_data)
mode_right = estimate_mode(right_skewed_data)

# Quartiles
q1_right, q2_right, q3_right = np.percentile(right_skewed_data, [25, 50, 75])

# Plot right-skewed
plt.figure(figsize=(14, 6))

plt.subplot(1, 2, 1)
counts, bins, _ = plt.hist(right_skewed_data, bins=100, density=True, alpha=0.7, color='skyblue', edgecolor='black')
plt.title('Right-Skewed (Positive Skew)\n(Gamma Distribution)')
plt.xlabel('Value')
plt.ylabel('Density')

# Plot mean, median, mode
plt.axvline(mean_right, color='red', linestyle='-', linewidth=2, label=f'Mean = {mean_right:.2f}')
plt.axvline(median_right, color='green', linestyle='-', linewidth=2, label=f'Median = {median_right:.2f}')
plt.axvline(mode_right, color='blue', linestyle='-', linewidth=2, label=f'Mode ≈ {mode_right:.2f}')

# Plot quartiles
plt.axvline(q1_right, color='orange', linestyle='--', linewidth=2, label=f'Q1 (25th %ile) = {q1_right:.2f}')
plt.axvline(q2_right, color='green', linestyle='--', linewidth=2, label=f'Q2 (50th %ile) = {q2_right:.2f}')  # Same as median
plt.axvline(q3_right, color='purple', linestyle='--', linewidth=2, label=f'Q3 (75th %ile) = {q3_right:.2f}')

plt.legend(fontsize=9)
plt.grid(True, alpha=0.3)

# -------------------------------
# Left-Skewed (Negative Skew) Distribution - Skew-Normal
# -------------------------------
a = -5
left_skewed_data = skewnorm.rvs(a, size=10000)

mean_left = np.mean(left_skewed_data)
median_left = np.median(left_skewed_data)
mode_left = estimate_mode(left_skewed_data)

# Quartiles
q1_left, q2_left, q3_left = np.percentile(left_skewed_data, [25, 50, 75])

# Plot left-skewed
plt.subplot(1, 2, 2)
counts, bins, _ = plt.hist(left_skewed_data, bins=100, density=True, alpha=0.7, color='salmon', edgecolor='black')
plt.title('Left-Skewed (Negative Skew)\n(Skew-Normal Distribution)')
plt.xlabel('Value')
plt.ylabel('Density')

# Plot mean, median, mode
plt.axvline(mean_left, color='red', linestyle='-', linewidth=2, label=f'Mean = {mean_left:.2f}')
plt.axvline(median_left, color='green', linestyle='-', linewidth=2, label=f'Median = {median_left:.2f}')
plt.axvline(mode_left, color='blue', linestyle='-', linewidth=2, label=f'Mode ≈ {mode_left:.2f}')

# Plot quartiles
plt.axvline(q1_left, color='orange', linestyle='--', linewidth=2, label=f'Q1 (25th %ile) = {q1_left:.2f}')
plt.axvline(q2_left, color='green', linestyle='--', linewidth=2, label=f'Q2 (50th %ile) = {q2_left:.2f}')
plt.axvline(q3_left, color='purple', linestyle='--', linewidth=2, label=f'Q3 (75th %ile) = {q3_left:.2f}')

plt.legend(fontsize=9)
plt.grid(True, alpha=0.3)

# Final layout
plt.tight_layout()
plt.show()

# Print skewness and quartile ranges
print(f"Right-skewed data - Skewness: {stats.skew(right_skewed_data):.3f}")
print(f"Right-skewed data - IQR (Q3 - Q1): {q3_right - q1_right:.3f}")
print(f"Left-skewed data - Skewness: {stats.skew(left_skewed_data):.3f}")
print(f"Left-skewed data - IQR (Q3 - Q1): {q3_left - q1_left:.3f}")
# Out:
# Right-skewed data - Skewness: 1.422
# Right-skewed data - IQR (Q3 - Q1): 3.468
# Left-skewed data - Skewness: -0.856
# Left-skewed data - IQR (Q3 - Q1): 0.831

# %% [markdown]
# # Otros tipos de gráficas

# %% [markdown]
# En esta sección veremos ejemplos de los distintos tipos de gráficas vistos en clase

# %%
# Llamamos al DataFrame otra vez para poder visualizar los datos de neuvo sin tener que estar regresando
df
# Out:
#              id                         nombre  semestre  promedio  ingresos  \
# 0     IDHFI3552  Caridad Leonor Padrón Cavazos         7        86   13580.0
# 1     IDVOH5097       Aurelio Fabiola Anguiano         4        89   15993.0
# 2     IDFYS5079          Omar Amalia Sepúlveda         8        89   11008.0
# 3     IDSCE4123   Pamela Aida Cuellar Valverde         5        62   30926.0
# 4     IDYMU9480          Óscar Olivárez Nájera         7        66   24968.0
# ...         ...                            ...       ...       ...       ...
# 9995  IDURC8308    Inés Cynthia Madrid Salinas         7        86   17337.0
# 9996  IDJLX9083                   Mitzy Puente        10        74       NaN
# 9997  IDNCQ0036                Raquel Longoria         3        91   26994.0
# 9998  IDWJQ8803           Lic. Andrea Cisneros        10        87       NaN
# 9999  IDLPD1164    Maximiliano Alfonso Fuentes         5        68   22850.0
#
#       opinion_campus  trabaja  distancia_universidad  edad tipo_vivienda  \
# 0                 10    False                    NaN    21        Propia
# 1                  4     True                    1.0    22      Alquiler
# 2                  4    False                    1.0    18        Propia
# 3                 10    False                    1.0    17        Propia
# 4                 10    False                    1.0    26      Alquiler
# ...              ...      ...                    ...   ...           ...
# 9995              10     True                    1.0    37      Alquiler
# 9996               1    False                   10.0    17      Alquiler
# 9997              10     True                    NaN    27        Propia
# 9998               7     True                    3.0    26      Alquiler
# 9999               9     True                    NaN    23        Propia
#
#       horas_estudio  desertor
# 0                29         0
# 1                 5         0
# 2                11         0
# 3                12         0
# 4                17         0
# ...             ...       ...
# 9995             70         0
# 9996             88         0
# 9997             71         0
# 9998             74         0
# 9999            100         0
#
# [10000 rows x 12 columns]

# %%
# Obtenemos sus propiedades estadísticas para seleccionar los mejores ejemplos para cada tipo de gráfica
df.describe()
# Out:
#            semestre      promedio      ingresos  opinion_campus  \
# count  10000.000000  10000.000000   8107.000000    10000.000000
# mean       5.497200     79.752400  20319.281485        7.271800
# std        2.893964     11.743368   8143.080849        2.833254
# min        1.000000     60.000000   8300.000000        1.000000
# 25%        3.000000     70.000000  14035.000000        5.000000
# 50%        6.000000     80.000000  19972.000000        8.000000
# 75%        8.000000     90.000000  25908.500000       10.000000
# max       10.000000    100.000000  49329.000000       10.000000
#
#        distancia_universidad          edad  horas_estudio      desertor
# count            7977.000000  10000.000000   10000.000000  10000.000000
# mean                4.264385     20.888600      50.270400      0.187600
# std                 3.632390      3.855733      35.786128      0.390412
# min                 1.000000     17.000000       1.000000      0.000000
# 25%                 1.000000     17.000000      16.000000      0.000000
# 50%                 3.000000     20.000000      50.000000      0.000000
# 75%                 7.000000     23.000000      85.000000      0.000000
# max                25.000000     39.000000     100.000000      1.000000

# %% [markdown]
# ## Matriz de correlación

# %%
# Graficamos la matriz de corrleación entre las variables "semestre" y "promedio"

correlation_matrix = df[['semestre', 'promedio']].corr()

# Plot heatmap
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", fmt=".2f")
plt.show()

# %% [markdown]
# ##

# %% [markdown]
# ## Boxplot

# %%
# Graficamos boxplot para la variable "semestre"

plt.figure(figsize=(6, 6))
sns.boxplot(data=df[['semestre']])
plt.show()

# %%
# Graficamos boxplot para la variable "ingresos"

plt.figure(figsize=(6, 6))
sns.boxplot(data=df[['ingresos']])
plt.show()

# %%
# Graficamos boxplot para la variable "edad"

plt.figure(figsize=(6, 6))
sns.boxplot(data=df[['edad']])
plt.show()

# %%
# Graficamos boxplot para la variable "horas_estudio"

plt.figure(figsize=(6, 6))
sns.boxplot(data=df[['horas_estudio']])
plt.show()

# %% [markdown]
# ## Pie chart

# %%
# Graficamos gráfica de pastel para la variable clase "desertor"

plt.figure(figsize=(6, 6))
df['desertor'].value_counts().plot.pie(autopct='%1.1f%%', cmap='coolwarm')
plt.title('Desertor')
plt.show()
